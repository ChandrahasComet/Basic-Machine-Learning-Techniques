# %%
import pandas as pd
import numpy as np
import sklearn
import scipy
from sklearn.svm import OneClassSVM
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report,accuracy_score

# %%
data = pd.read_csv('creditcard.csv')
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
data = data.sample(frac=0.1,random_state=1)
data.shape
# Out:
# (28481, 31)

# %%
data.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  119907.0 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467   78340.0 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900   82382.0 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513    31717.0 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700   80923.0  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 169876  0.292491 -0.523020  0.358468  ... -0.075208  0.045536  0.380739
# 127467  0.321552  0.435975 -0.704298  ... -0.128619 -0.368565  0.090660
# 137900  0.706252 -0.064966 -0.463271  ... -0.305402 -0.774704 -0.123884
# 21513   0.681867 -0.031641  0.383872  ... -0.220815 -0.419013 -0.239197
# 134700  0.373692 -0.287204 -0.084482  ... -0.160161 -0.430404 -0.076738
#
#              V24       V25       V26       V27       V28  Amount  Class
# 169876  0.023440 -2.220686 -0.201146  0.066501  0.221180    1.79      0
# 127467  0.401147 -0.261034  0.080621  0.162427  0.059456    1.98      0
# 137900 -0.495687 -0.018148  0.121679  0.249050  0.092516    0.89      0
# 21513   0.009967  0.232829  0.814177  0.098797 -0.004273   15.98      0
# 134700  0.258708  0.552170  0.370701 -0.034255  0.041709    0.76      0
#
# [5 rows x 31 columns]

# %%
valid =  data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data.corr(),annot=True,cmap = 'RdYlGn')
# Out:
# <AxesSubplot: >

# %%
model = OneClassSVM(kernel = 'rbf', degree = 3,gamma = 0.1,nu=0.05, max_iter=-1 )

# %%
X = data.iloc[:,0:30]
Y = data['Class']

# %%
X.shape
# Out:
# (28481, 30)

# %%
X.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  119907.0 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467   78340.0 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900   82382.0 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513    31717.0 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700   80923.0  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 169876  0.292491 -0.523020  0.358468  ... -0.196039 -0.075208  0.045536
# 127467  0.321552  0.435975 -0.704298  ... -0.009041 -0.128619 -0.368565
# 137900  0.706252 -0.064966 -0.463271  ...  0.206028 -0.305402 -0.774704
# 21513   0.681867 -0.031641  0.383872  ...  0.315823 -0.220815 -0.419013
# 134700  0.373692 -0.287204 -0.084482  ... -0.105286 -0.160161 -0.430404
#
#              V23       V24       V25       V26       V27       V28  Amount
# 169876  0.380739  0.023440 -2.220686 -0.201146  0.066501  0.221180    1.79
# 127467  0.090660  0.401147 -0.261034  0.080621  0.162427  0.059456    1.98
# 137900 -0.123884 -0.495687 -0.018148  0.121679  0.249050  0.092516    0.89
# 21513  -0.239197  0.009967  0.232829  0.814177  0.098797 -0.004273   15.98
# 134700 -0.076738  0.258708  0.552170  0.370701 -0.034255  0.041709    0.76
#
# [5 rows x 30 columns]

# %%
X = X.reset_index(drop=True)

# %%
X.head(5)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  119907.0 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 1   78340.0 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 2   82382.0 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 3   31717.0 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 4   80923.0  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0  0.292491 -0.523020  0.358468  ... -0.196039 -0.075208  0.045536  0.380739
# 1  0.321552  0.435975 -0.704298  ... -0.009041 -0.128619 -0.368565  0.090660
# 2  0.706252 -0.064966 -0.463271  ...  0.206028 -0.305402 -0.774704 -0.123884
# 3  0.681867 -0.031641  0.383872  ...  0.315823 -0.220815 -0.419013 -0.239197
# 4  0.373692 -0.287204 -0.084482  ... -0.105286 -0.160161 -0.430404 -0.076738
#
#         V24       V25       V26       V27       V28  Amount
# 0  0.023440 -2.220686 -0.201146  0.066501  0.221180    1.79
# 1  0.401147 -0.261034  0.080621  0.162427  0.059456    1.98
# 2 -0.495687 -0.018148  0.121679  0.249050  0.092516    0.89
# 3  0.009967  0.232829  0.814177  0.098797 -0.004273   15.98
# 4  0.258708  0.552170  0.370701 -0.034255  0.041709    0.76
#
# [5 rows x 30 columns]

# %%
model.fit(X)
# Out:
# OneClassSVM(gamma=0.1, nu=0.05)

# %%
y_pred = model.predict(X)

# %%
print(accuracy_score(Y,y_pred))
# Out:
# 0.001088444928197746

# %%
 print(classification_report(Y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         0
#            0       0.00      0.00      0.00     28432
#            1       0.00      0.63      0.00        49
#
#     accuracy                           0.00     28481
#    macro avg       0.00      0.21      0.00     28481
# weighted avg       0.00      0.00      0.00     28481
# C:\Users\chand\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chand\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chand\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chand\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chand\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chand\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
